# %% [markdown]
# # 🏆 Jan 30: Pandas Core Practice Challenge
#
# Time to test your knowledge! Follow the tasks below.

# %%
import pandas as pd

# %% [markdown]
# ### Task 1: Create the Dataset
# Create a CSV named `sales_data.csv` with the following content and then read it into a DataFrame.

# %%
data = """Date,Store,Item,Quantity,Price
2026-01-26,East,Apple,50,0.5
2026-01-26,West,Banana,100,0.3
2026-01-27,East,Apple,30,0.5
2026-01-27,North,Cherry,20,2.0
2026-01-28,West,Apple,45,0.5
2026-01-29,North,Banana,80,0.3
2026-01-30,East,Cherry,15,2.0
"""
with open('sales_data.csv', 'w') as f:
    f.write(data)

df_sales = pd.read_csv('sales_data.csv')
df_sales

# %% [markdown]
# ### Task 2: Inspection
# 1. Show the first 3 rows.
# 2. How many rows and columns are there?
# 3. Display the data types of all columns.

# %%
# Your code here

# %% [markdown]
# ### Task 3: Filtering
# 1. Filter the sales for the 'East' store only.
# 2. Filter sales where the Quantity is greater than 50.

# %%
# Your code here

# %% [markdown]
# ### Task 4: Sorting
# 1. Sort the data by 'Quantity' in descending order.
# 2. Sort the data by 'Store' (alphabetical) and then 'Price' (lowest to highest).

# %%
# Your code here
