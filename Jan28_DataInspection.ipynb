# %% [markdown]
# # 🔍 Jan 28: Data Inspection - Practice
#
# Let's practice how to quickly explore and understand a dataset.

# %%
import pandas as pd

# %% [markdown]
# ### 1. Load the Practice Data
# We'll use the `practice_data.csv` created yesterday.

# %%
df = pd.read_csv('practice_data.csv')
df

# %% [markdown]
# ### 2. Basic Info & Shape
# Print the shape of the dataframe and use `.info()`.

# %%
print("Dataset Shape:", df.shape)
print("\n--- Info ---")
df.info()

# %% [markdown]
# ### 3. Statistics & Columns
# Display the descriptive statistics and the column names.

# %%
print("Columns:", df.columns)
print("\n--- Descriptive Statistics ---")
print(df.describe())

# %% [markdown]
# ### 4. Value Counts
# Use `value_counts()` on the 'Product' column.

# %%
print("Product Distribution:\n", df['Product'].value_counts())
